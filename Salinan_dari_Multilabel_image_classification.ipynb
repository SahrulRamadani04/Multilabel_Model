# %% [markdown]
# <a href="https://colab.research.google.com/github/SahrulRamadani04/Multilabel_Model/blob/main/Salinan_dari_Multilabel_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.layers import BatchNormalization

# %%
import os
os.environ["KAGGLE_USERNAME"] = "sahrulramadani" # Ganti dengan username Kaggle Anda
os.environ["KAGGLE_KEY"] = "d79bcef4b52a3aa915ded336c95d52db" # Ganti dengan key yang ada di kaggle.json

# %%
# !kaggle datasets download -d sahrulramadani/multilabel-dataset
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/sahrulramadani/multilabel-dataset
# License(s): CC-BY-SA-4.0
# Downloading multilabel-dataset.zip to /content
# 100% 964M/967M [00:46<00:00, 23.6MB/s]
# 100% 967M/967M [00:46<00:00, 21.6MB/s]

# %%
# prompt: unzip file movie-classifier.zip

# !unzip multilabel-dataset.zip
# Out:
# Archive:  multilabel-dataset.zip
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar001.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar002.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar003.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar004.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar005.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar006.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar007.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar008.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar009.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar010.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar011.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar012.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar013.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar014.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar015.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar016.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar017.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar018.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar019.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar020.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar021.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar022.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar023.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar024.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar025.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar026.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar027.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar028.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar029.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar030.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar031.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar032.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar033.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar034.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar035.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar036.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar037.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar038.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar039.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar040.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar041.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar042.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar043.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar044.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar045.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar046.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar047.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar048.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar049.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar050.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar051.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar052.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar053.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar054.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar055.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar056.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar057.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar058.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar059.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar060.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar061.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar062.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar063.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar064.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar065.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar066.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar067.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar068.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar069.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar070.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar071.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar072.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar073.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar074.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar075.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar076.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar077.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar078.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar079.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar080.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar081.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar082.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar083.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar084.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar085.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar086.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar087.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar088.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar089.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar090.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar091.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar092.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar093.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar094.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar095.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar096.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar097.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar098.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar099.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar100.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar101.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar102.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar103.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar104.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar105.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar106.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar107.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar108.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar109.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar110.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar111.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar112.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar113.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar114.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar115.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar116.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar117.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar118.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar119.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar120.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar121.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar122.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar123.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar124.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar125.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar126.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar127.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar128.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar129.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar130.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar131.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar132.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar133.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar134.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar135.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar136.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar137.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar138.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar139.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar140.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar141.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar142.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar143.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar144.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar145.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar146.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar147.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar148.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar149.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar150.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar151.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar152.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar153.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar154.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar155.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar156.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar157.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar158.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar159.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar160.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar161.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar162.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar163.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar164.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar165.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar166.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar167.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar168.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar169.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar170.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar171.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar172.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar173.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar174.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar175.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar176.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar177.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar178.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar179.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar180.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar181.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar182.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar183.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar184.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar185.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar186.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar187.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar188.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar189.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar190.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar191.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar192.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar193.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar194.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar195.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar196.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar197.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar198.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar199.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar200.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar201.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar202.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar203.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar204.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar205.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar206.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar207.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar208.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar209.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar210.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar211.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar212.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar213.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar214.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar215.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar216.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar217.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar218.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar219.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar220.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar221.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar222.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar223.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar224.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar225.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar226.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar227.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar228.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar229.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar230.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar231.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar232.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar233.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar234.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar235.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar236.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar237.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar238.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar239.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar240.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar241.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar242.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar243.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar244.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar245.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar246.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar247.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar248.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar249.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar250.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar251.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar252.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar253.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar254.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar255.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar256.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar257.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar258.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar259.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar260.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar261.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar262.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar263.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar264.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar265.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar266.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar267.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar268.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar269.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar270.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar271.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar272.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar273.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar274.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar275.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar276.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar277.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar278.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar279.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar280.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar281.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar282.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar283.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar284.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar285.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar286.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar287.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar288.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar289.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar290.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar291.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar292.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar293.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar294.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar295.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar296.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar297.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar298.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar299.jpg
#   inflating: Tugas 3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar300.jpg
#   inflating: Tugas 3/traindataset_SahrulRamadani_202355202155.csv

# %%
#Now let us read metadata to get our Y values (multiple lables)
df = pd.read_csv('/content/Tugas3/traindataset_SahrulRamadani_202355202155.csv')
print(df.head())     # printing first five rows of the file
print(df.columns)

df = df.iloc[:2000]  #Loading only first 1000 datapoints for memory reasons
#Need to read images using the tag from metadata.
#Otherwise, if read directly from the folder then images may not correspond to
#the metadata from the csv file.
# Out:
#           Id             Objek  Sisir   Buku   Bedak   Handphone
# 0  Gambar001  ['Sisir','Buku']      1      1       0           0
# 1  Gambar002  ['Sisir','Buku']      1      1       0           0
# 2  Gambar003  ['Sisir','Buku']      1      1       0           0
# 3  Gambar004  ['Sisir','Buku']      1      1       0           0
# 4  Gambar005  ['Sisir','Buku']      1      1       0           0
# Index(['Id', 'Objek', 'Sisir', ' Buku', ' Bedak', ' Handphone'], dtype='object')

# %%
SIZE = 224
X_dataset = []
#Define image_directory before it's used in the loop
image_directory = '/content/Tugas3/DatasetMultilabel_SahrulRamadani_202355202155/' # Change to extracted image directory
for i in tqdm(range(df.shape[0])):
    # Added '/' as a separator between image_directory and filename
    img = image.load_img(image_directory + '/' + df['Id'][i]+'.jpg', target_size=(SIZE,SIZE,3))
    img = image.img_to_array(img)
    img = img/255.
    X_dataset.append(img)

X = np.array(X_dataset)
# Out:
# 100%|██████████| 300/300 [00:26<00:00, 11.21it/s]

# %%
#
print(df['Id'][100])  #King Kong
# Out:
# Gambar101

# %%
print(df['Objek'][100])  #Tagged as multiple Genres.
# Out:
# ['Buku','Sisir','Bedak']

# %%
#Id and Genre are not labels to be trained. So drop them from the dataframe.
#No need to convert to categorical as the dataset is already in the right format.
y = np.array(df.drop(['Id', 'Objek'], axis=1))

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20, test_size=0.3)

# %%
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=(5, 5), activation="relu", input_shape=(SIZE,SIZE,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='sigmoid'))

#Do not use softmax for multilabel classification
#Softmax is useful for mutually exclusive classes, either cat or dog but not both.
#Also, softmax outputs all add to 1. So good for multi class problems where each
#class is given a probability and all add to 1. Highest one wins.

#Sigmoid outputs probability. Can be used for non-mutually exclusive problems.
#like multi label, in this example.
#But, also good for binary mutually exclusive (cat or not cat).

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 220, 220, 16)        │           1,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 220, 220, 16)        │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 110, 110, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 110, 110, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 106, 106, 32)        │          12,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 53, 53, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 53, 53, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 53, 53, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 49, 49, 64)          │          51,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 24, 24, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 20, 20, 64)          │         102,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 10, 10, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6400)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         819,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 996,324 (3.80 MB)
#  Trainable params: 995,972 (3.80 MB)
#  Non-trainable params: 352 (1.38 KB)

# %%
#Binary cross entropy of each label. So no really a binary classification problem but
#Calculating binary cross entropy for each label.
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=150, validation_data=(X_test, y_test), batch_size=16)
# Out:
# Epoch 1/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4760 - loss: 0.1055 - val_accuracy: 0.4667 - val_loss: 0.8991
# Epoch 2/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4647 - loss: 0.0666 - val_accuracy: 0.4333 - val_loss: 0.8470
# Epoch 3/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4345 - loss: 0.0959 - val_accuracy: 0.3667 - val_loss: 0.7941
# Epoch 4/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.4423 - loss: 0.0633 - val_accuracy: 0.3333 - val_loss: 0.7113
# Epoch 5/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.4495 - loss: 0.0637 - val_accuracy: 0.2889 - val_loss: 0.7473
# Epoch 6/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5760 - loss: 0.0802 - val_accuracy: 0.3333 - val_loss: 0.7466
# Epoch 7/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4815 - loss: 0.0642 - val_accuracy: 0.3333 - val_loss: 0.7420
# Epoch 8/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4884 - loss: 0.0670 - val_accuracy: 0.4111 - val_loss: 0.7563
# Epoch 9/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5125 - loss: 0.0524 - val_accuracy: 0.4333 - val_loss: 0.7761
# Epoch 10/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5889 - loss: 0.0369 - val_accuracy: 0.4111 - val_loss: 0.7608
# Epoch 11/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4785 - loss: 0.0465 - val_accuracy: 0.3444 - val_loss: 0.7147
# Epoch 12/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5435 - loss: 0.0393 - val_accuracy: 0.3444 - val_loss: 0.7606
# Epoch 13/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5531 - loss: 0.0460 - val_accuracy: 0.2778 - val_loss: 0.8899
# Epoch 14/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5260 - loss: 0.0290 - val_accuracy: 0.2778 - val_loss: 0.9215
# Epoch 15/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5542 - loss: 0.0758 - val_accuracy: 0.2889 - val_loss: 0.7918
# Epoch 16/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5882 - loss: 0.0398 - val_accuracy: 0.3111 - val_loss: 0.7854
# Epoch 17/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5359 - loss: 0.0788 - val_accuracy: 0.3333 - val_loss: 1.0037
# Epoch 18/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5831 - loss: 0.0711 - val_accuracy: 0.2778 - val_loss: 0.8562
# Epoch 19/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5200 - loss: 0.0585 - val_accuracy: 0.3222 - val_loss: 1.1610
# Epoch 20/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5405 - loss: 0.0819 - val_accuracy: 0.3222 - val_loss: 1.2661
# Epoch 21/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5529 - loss: 0.0944 - val_accuracy: 0.2333 - val_loss: 4.2999
# Epoch 22/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5127 - loss: 0.0751 - val_accuracy: 0.2111 - val_loss: 4.3327
# Epoch 23/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4806 - loss: 0.0834 - val_accuracy: 0.1667 - val_loss: 2.1538
# Epoch 24/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5316 - loss: 0.0526 - val_accuracy: 0.2778 - val_loss: 1.2314
# Epoch 25/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6031 - loss: 0.0551 - val_accuracy: 0.3111 - val_loss: 1.1757
# Epoch 26/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5706 - loss: 0.0569 - val_accuracy: 0.3667 - val_loss: 1.1538
# Epoch 27/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5769 - loss: 0.0509 - val_accuracy: 0.4000 - val_loss: 1.2429
# Epoch 28/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5307 - loss: 0.0941 - val_accuracy: 0.3889 - val_loss: 1.1253
# Epoch 29/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5381 - loss: 0.0371 - val_accuracy: 0.3444 - val_loss: 1.9540
# Epoch 30/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4989 - loss: 0.0504 - val_accuracy: 0.3556 - val_loss: 2.2825
# Epoch 31/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6226 - loss: 0.0364 - val_accuracy: 0.3222 - val_loss: 1.7731
# Epoch 32/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6591 - loss: 0.0462 - val_accuracy: 0.3556 - val_loss: 1.0130
# Epoch 33/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5416 - loss: 0.0788 - val_accuracy: 0.5778 - val_loss: 2.1125
# Epoch 34/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5212 - loss: 0.1071 - val_accuracy: 0.3333 - val_loss: 2.1549
# Epoch 35/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4841 - loss: 0.1423 - val_accuracy: 0.2222 - val_loss: 2.4324
# Epoch 36/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4994 - loss: 0.1496 - val_accuracy: 0.2444 - val_loss: 1.8975
# Epoch 37/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5397 - loss: 0.1210 - val_accuracy: 0.2222 - val_loss: 1.3274
# Epoch 38/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4985 - loss: 0.1007 - val_accuracy: 0.2333 - val_loss: 1.0593
# Epoch 39/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5102 - loss: 0.0623 - val_accuracy: 0.2444 - val_loss: 1.0753
# Epoch 40/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5719 - loss: 0.1145 - val_accuracy: 0.3444 - val_loss: 1.0321
# Epoch 41/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6035 - loss: 0.0707 - val_accuracy: 0.4000 - val_loss: 1.0800
# Epoch 42/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5387 - loss: 0.0649 - val_accuracy: 0.3111 - val_loss: 1.1176
# Epoch 43/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5762 - loss: 0.0907 - val_accuracy: 0.4889 - val_loss: 1.3852
# Epoch 44/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5628 - loss: 0.0850 - val_accuracy: 0.4111 - val_loss: 1.3663
# Epoch 45/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5158 - loss: 0.1065 - val_accuracy: 0.4222 - val_loss: 1.4345
# Epoch 46/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5601 - loss: 0.0951 - val_accuracy: 0.4000 - val_loss: 1.3237
# Epoch 47/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6039 - loss: 0.0847 - val_accuracy: 0.3333 - val_loss: 1.0160
# Epoch 48/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5734 - loss: 0.1174 - val_accuracy: 0.3444 - val_loss: 1.0934
# Epoch 49/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5634 - loss: 0.0479 - val_accuracy: 0.3889 - val_loss: 1.0939
# Epoch 50/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5790 - loss: 0.0992 - val_accuracy: 0.3222 - val_loss: 1.0521
# Epoch 51/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6747 - loss: 0.0505 - val_accuracy: 0.3111 - val_loss: 1.0396
# Epoch 52/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5983 - loss: 0.0217 - val_accuracy: 0.3222 - val_loss: 1.0423
# Epoch 53/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5913 - loss: 0.0935 - val_accuracy: 0.3444 - val_loss: 1.0519
# Epoch 54/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6613 - loss: 0.1118 - val_accuracy: 0.4111 - val_loss: 1.1005
# Epoch 55/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6097 - loss: 0.0578 - val_accuracy: 0.3889 - val_loss: 0.9490
# Epoch 56/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5984 - loss: 0.0385 - val_accuracy: 0.3444 - val_loss: 0.9071
# Epoch 57/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5356 - loss: 0.0658 - val_accuracy: 0.3667 - val_loss: 1.0881
# Epoch 58/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6658 - loss: 0.0365 - val_accuracy: 0.4000 - val_loss: 1.0904
# Epoch 59/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5598 - loss: 0.0382 - val_accuracy: 0.4222 - val_loss: 1.0477
# Epoch 60/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6095 - loss: 0.0447 - val_accuracy: 0.4778 - val_loss: 1.2397
# Epoch 61/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5978 - loss: 0.0800 - val_accuracy: 0.4556 - val_loss: 1.1786
# Epoch 62/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5745 - loss: 0.0291 - val_accuracy: 0.4222 - val_loss: 1.1237
# Epoch 63/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5677 - loss: 0.0856 - val_accuracy: 0.4333 - val_loss: 1.0820
# Epoch 64/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5666 - loss: 0.0724 - val_accuracy: 0.3556 - val_loss: 0.9904
# Epoch 65/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6009 - loss: 0.0694 - val_accuracy: 0.4889 - val_loss: 1.2565
# Epoch 66/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4708 - loss: 0.0624 - val_accuracy: 0.4667 - val_loss: 1.3340
# Epoch 67/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5439 - loss: 0.0655 - val_accuracy: 0.3333 - val_loss: 1.1430
# Epoch 68/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5241 - loss: 0.0793 - val_accuracy: 0.3111 - val_loss: 1.0517
# Epoch 69/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5844 - loss: 0.0444 - val_accuracy: 0.3667 - val_loss: 1.0375
# Epoch 70/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6281 - loss: 0.0770 - val_accuracy: 0.3667 - val_loss: 1.0179
# Epoch 71/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5355 - loss: 0.0494 - val_accuracy: 0.3444 - val_loss: 0.9974
# Epoch 72/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6440 - loss: 0.0306 - val_accuracy: 0.3111 - val_loss: 0.9304
# Epoch 73/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6276 - loss: 0.0473 - val_accuracy: 0.3444 - val_loss: 0.9896
# Epoch 74/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5874 - loss: 0.0489 - val_accuracy: 0.3889 - val_loss: 1.0287
# Epoch 75/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5397 - loss: 0.0585 - val_accuracy: 0.4222 - val_loss: 1.1813
# Epoch 76/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5874 - loss: 0.0303 - val_accuracy: 0.4222 - val_loss: 1.2758
# Epoch 77/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6630 - loss: 0.0503 - val_accuracy: 0.3444 - val_loss: 1.1485
# Epoch 78/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6007 - loss: 0.0404 - val_accuracy: 0.4111 - val_loss: 1.2057
# Epoch 79/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5574 - loss: 0.0275 - val_accuracy: 0.4222 - val_loss: 1.1401
# Epoch 80/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6853 - loss: 0.0365 - val_accuracy: 0.3556 - val_loss: 1.0663
# Epoch 81/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6292 - loss: 0.0562 - val_accuracy: 0.3667 - val_loss: 0.9747
# Epoch 82/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6641 - loss: 0.0150 - val_accuracy: 0.3444 - val_loss: 1.0104
# Epoch 83/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6073 - loss: 0.0420 - val_accuracy: 0.3444 - val_loss: 0.9996
# Epoch 84/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5610 - loss: 0.0280 - val_accuracy: 0.3667 - val_loss: 1.0512
# Epoch 85/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6176 - loss: 0.0339 - val_accuracy: 0.3556 - val_loss: 1.0798
# Epoch 86/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6701 - loss: 0.0419 - val_accuracy: 0.3778 - val_loss: 1.1297
# Epoch 87/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5743 - loss: 0.0458 - val_accuracy: 0.4333 - val_loss: 1.3369
# Epoch 88/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5595 - loss: 0.0335 - val_accuracy: 0.5667 - val_loss: 2.5095
# Epoch 89/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6401 - loss: 0.0485 - val_accuracy: 0.4889 - val_loss: 1.6482
# Epoch 90/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6723 - loss: 0.0529 - val_accuracy: 0.4222 - val_loss: 1.0648
# Epoch 91/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6722 - loss: 0.0240 - val_accuracy: 0.4000 - val_loss: 1.0795
# Epoch 92/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6391 - loss: 0.0277 - val_accuracy: 0.4444 - val_loss: 1.1008
# Epoch 93/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6779 - loss: 0.0304 - val_accuracy: 0.4667 - val_loss: 1.2827
# Epoch 94/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6758 - loss: 0.0283 - val_accuracy: 0.4333 - val_loss: 1.2937
# Epoch 95/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6743 - loss: 0.0846 - val_accuracy: 0.3000 - val_loss: 1.2394
# Epoch 96/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6972 - loss: 0.0585 - val_accuracy: 0.2222 - val_loss: 1.1247
# Epoch 97/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5991 - loss: 0.0763 - val_accuracy: 0.3222 - val_loss: 1.0455
# Epoch 98/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6469 - loss: 0.0294 - val_accuracy: 0.3444 - val_loss: 0.9963
# Epoch 99/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6559 - loss: 0.0904 - val_accuracy: 0.4333 - val_loss: 1.0519
# Epoch 100/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6699 - loss: 0.0662 - val_accuracy: 0.3889 - val_loss: 1.2220
# Epoch 101/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6602 - loss: 0.0462 - val_accuracy: 0.4333 - val_loss: 1.3083
# Epoch 102/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6886 - loss: 0.0267 - val_accuracy: 0.4889 - val_loss: 1.2166
# Epoch 103/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7062 - loss: 0.0570 - val_accuracy: 0.4222 - val_loss: 1.2374
# Epoch 104/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5611 - loss: 0.0611 - val_accuracy: 0.4444 - val_loss: 1.0451
# Epoch 105/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6254 - loss: 0.0259 - val_accuracy: 0.4111 - val_loss: 1.0792
# Epoch 106/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6590 - loss: 0.0331 - val_accuracy: 0.3667 - val_loss: 1.0533
# Epoch 107/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6323 - loss: 0.0327 - val_accuracy: 0.3778 - val_loss: 1.0226
# Epoch 108/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6853 - loss: 0.0323 - val_accuracy: 0.4111 - val_loss: 1.1326
# Epoch 109/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7430 - loss: 0.0199 - val_accuracy: 0.4667 - val_loss: 1.1656
# Epoch 110/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7360 - loss: 0.0278 - val_accuracy: 0.4222 - val_loss: 1.1386
# Epoch 111/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6065 - loss: 0.0430 - val_accuracy: 0.4333 - val_loss: 1.1745
# Epoch 112/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6783 - loss: 0.0206 - val_accuracy: 0.4444 - val_loss: 1.1910
# Epoch 113/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8186 - loss: 0.0222 - val_accuracy: 0.4444 - val_loss: 1.2393
# Epoch 114/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6674 - loss: 0.0348 - val_accuracy: 0.4333 - val_loss: 1.3279
# Epoch 115/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7561 - loss: 0.0249 - val_accuracy: 0.6000 - val_loss: 1.2370
# Epoch 116/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8065 - loss: 0.0464 - val_accuracy: 0.5556 - val_loss: 1.2009
# Epoch 117/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7885 - loss: 0.0339 - val_accuracy: 0.5222 - val_loss: 1.1227
# Epoch 118/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7384 - loss: 0.0264 - val_accuracy: 0.4889 - val_loss: 1.2146
# Epoch 119/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6680 - loss: 0.0231 - val_accuracy: 0.4778 - val_loss: 1.2640
# Epoch 120/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7320 - loss: 0.0219 - val_accuracy: 0.4778 - val_loss: 1.1736
# Epoch 121/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7586 - loss: 0.0308 - val_accuracy: 0.4778 - val_loss: 1.2871
# Epoch 122/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6475 - loss: 0.0248 - val_accuracy: 0.4444 - val_loss: 1.3502
# Epoch 123/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7020 - loss: 0.0251 - val_accuracy: 0.4667 - val_loss: 1.5076
# Epoch 124/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7911 - loss: 0.0310 - val_accuracy: 0.4889 - val_loss: 1.2697
# Epoch 125/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6382 - loss: 0.0204 - val_accuracy: 0.4222 - val_loss: 1.3301
# Epoch 126/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6667 - loss: 0.0248 - val_accuracy: 0.5000 - val_loss: 1.4476
# Epoch 127/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7190 - loss: 0.0124 - val_accuracy: 0.5111 - val_loss: 1.6070
# Epoch 128/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7546 - loss: 0.0143 - val_accuracy: 0.4778 - val_loss: 1.6548
# Epoch 129/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7227 - loss: 0.0221 - val_accuracy: 0.5222 - val_loss: 1.6694
# Epoch 130/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6913 - loss: 0.0919 - val_accuracy: 0.5333 - val_loss: 1.5744
# Epoch 131/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6462 - loss: 0.0294 - val_accuracy: 0.5111 - val_loss: 1.3887
# Epoch 132/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7196 - loss: 0.0779 - val_accuracy: 0.5556 - val_loss: 1.3831
# Epoch 133/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7379 - loss: 0.0337 - val_accuracy: 0.5333 - val_loss: 1.3257
# Epoch 134/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6500 - loss: 0.0284 - val_accuracy: 0.5333 - val_loss: 1.1948
# Epoch 135/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7641 - loss: 0.0204 - val_accuracy: 0.5889 - val_loss: 1.6037
# Epoch 136/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7640 - loss: 0.0275 - val_accuracy: 0.5778 - val_loss: 1.5709
# Epoch 137/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7105 - loss: 0.0413 - val_accuracy: 0.4222 - val_loss: 1.2535
# Epoch 138/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7556 - loss: 0.0184 - val_accuracy: 0.3667 - val_loss: 1.3107
# Epoch 139/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7274 - loss: 0.0156 - val_accuracy: 0.3778 - val_loss: 1.3093
# Epoch 140/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7350 - loss: 0.0313 - val_accuracy: 0.3778 - val_loss: 1.2817
# Epoch 141/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7065 - loss: 0.0408 - val_accuracy: 0.3556 - val_loss: 1.1498
# Epoch 142/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7020 - loss: 0.0346 - val_accuracy: 0.3778 - val_loss: 1.1888
# Epoch 143/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7632 - loss: 0.0257 - val_accuracy: 0.3556 - val_loss: 1.1623
# Epoch 144/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7384 - loss: 0.0329 - val_accuracy: 0.4000 - val_loss: 1.1459
# Epoch 145/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7530 - loss: 0.0585 - val_accuracy: 0.3667 - val_loss: 1.2136
# Epoch 146/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7609 - loss: 0.0183 - val_accuracy: 0.3667 - val_loss: 1.2721
# Epoch 147/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7242 - loss: 0.0269 - val_accuracy: 0.4222 - val_loss: 1.3758
# Epoch 148/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7334 - loss: 0.0432 - val_accuracy: 0.4667 - val_loss: 1.4069
# Epoch 149/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7200 - loss: 0.0900 - val_accuracy: 0.3889 - val_loss: 1.1511
# Epoch 150/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7306 - loss: 0.0142 - val_accuracy: 0.3889 - val_loss: 1.1656

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Validate on an image
#img = image.load_img('/content/Multi_Label_dataset/Images/tt0085318.jpg', target_size=(SIZE,SIZE,3))
# Assuming 'ddlj.jpg' is in '/content/Multi_Label_dataset/Images/'
img = image.load_img('/content/Tugas3/DatasetMultilabel_SahrulRamadani_202355202155/Gambar187.jpg', target_size=(SIZE,SIZE,3))

img = image.img_to_array(img)
img = img/255.
plt.imshow(img)
img = np.expand_dims(img, axis=0)

classes = np.array(df.columns[2:]) #Get array of all classes
proba = model.predict(img)  #Get probabilities for each class
sorted_categories = np.argsort(proba[0])[:-11:-1]  #Get class names for top 10 categories
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
#Print classes and corresponding probabilities
for i in range(4):
    print("{}".format(classes[sorted_categories[i]])+" ({:.3})".format(proba[0][sorted_categories[i]]))
# Out:
#  Handphone (1.0)
#  Bedak (1.0)
#  Buku (1.0)
# Sisir (8.14e-10)

# %%
###################################################

_, acc = model.evaluate(X_test, y_test)
print("Accuracy = ", (acc * 100.0), "%")

################################################################
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 546ms/step - accuracy: 0.3546 - loss: 1.1886
# Accuracy =  38.88888955116272 %

# %%
# prompt: berikan code evaluasi model

from sklearn.metrics import classification_report, confusion_matrix

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert probabilities to class labels (e.g., using a threshold)
y_pred_classes = (y_pred > 0.5).astype(int)  # Assuming 0.5 as the threshold

# Calculate and print the classification report
print(classification_report(y_test, y_pred_classes, target_names=classes))


# Calculate and print the confusion matrix (optional)
# Note: Confusion matrices are best visualized for binary or few-class problems
# For multi-label, confusion matrix for each label is more informative
for i in range(len(classes)):
  print(f"Confusion Matrix for {classes[i]}:")
  print(confusion_matrix(y_test[:,i], y_pred_classes[:,i]))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step
#               precision    recall  f1-score   support
#
#        Sisir       0.78      0.93      0.84        67
#         Buku       0.91      0.92      0.91        63
#        Bedak       0.88      0.67      0.76        75
#    Handphone       0.81      0.86      0.84        65
#
#    micro avg       0.84      0.84      0.84       270
#    macro avg       0.84      0.84      0.84       270
# weighted avg       0.84      0.84      0.83       270
#  samples avg       0.84      0.83      0.82       270
#
# Confusion Matrix for Sisir:
# [[ 5 18]
#  [ 5 62]]
# Confusion Matrix for  Buku:
# [[21  6]
#  [ 5 58]]
# Confusion Matrix for  Bedak:
# [[ 8  7]
#  [25 50]]
# Confusion Matrix for  Handphone:
# [[12 13]
#  [ 9 56]]
